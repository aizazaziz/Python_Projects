# %% [markdown]
# <a href="https://colab.research.google.com/github/aizazaziz/Python_Projects/blob/master/Chat_Bot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import torch
import torch.nn as nn
from torch.nn import functional as F
torch.manual_seed(1337)
import pandas as pd

# %%
with open ("input.txt", 'r', encoding='utf-8') as f:
  text = f.read()

# %%
len(text)
# Out:
# 1115394

# %%
print(text[:10])
# Out:
# First Citi

# %%
data

# %%
n = int(0.9*len(data))
td = data[:n]
vd = data[n:]
